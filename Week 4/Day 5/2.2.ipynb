# %% [markdown]
# # Clean a messy dataset using Pandas, handling missing values and outliers.

# %%
import pandas as pd 
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#       id                                              title  Rating maincateg  \
# 0   2242                            Casuals For Men  (Blue)     3.8       Men
# 1  20532                           Women Black Flats Sandal     3.9     Women
# 2  10648                           Women Gold Wedges Sandal     3.9     Women
# 3  20677  Men's Height Increasing High Heel Formal Party...     3.9       Men
# 4  12593                             Loafers For Men  (Tan)     3.9       Men
#
#    platform  actprice1  norating1  noreviews1  star_5f  star_4f  star_3f  \
# 0  Flipkart        999      27928        3543  14238.0     4295     3457
# 1  Flipkart        499       3015         404   1458.0      657      397
# 2  Flipkart        999        449          52    229.0       70       71
# 3  Flipkart       2999        290          40    141.0       51       49
# 4  Flipkart        999       2423         326   1265.0      414      293
#
#    star_2f  star_1f  fulfilled1
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# Rating        203
# maincateg      67
# platform        0
# actprice1       0
# norating1       0
# noreviews1      0
# star_5f        68
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f       186
# fulfilled1      0
# dtype: int64

# %%
df.fillna(value=1)
# Out:
#          id                                              title  Rating  \
# 0      2242                            Casuals For Men  (Blue)     3.8
# 1     20532                           Women Black Flats Sandal     3.9
# 2     10648                           Women Gold Wedges Sandal     3.9
# 3     20677  Men's Height Increasing High Heel Formal Party...     3.9
# 4     12593                             Loafers For Men  (Tan)     3.9
# ...     ...                                                ...     ...
# 5239  14033                       Women Off White Flats Sandal     1.0
# 5240    297                             Slip On For Men  (Tan)     3.9
# 5241  18733                            Women Grey Heels Sandal     3.8
# 5242   6162  Womens Casual Comfort Stylish Black High Heel ...     3.9
# 5243  13574    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9
#
#      maincateg  platform  actprice1  norating1  noreviews1  star_5f  star_4f  \
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# Rating        203
# maincateg      67
# platform        0
# actprice1       0
# norating1       0
# noreviews1      0
# star_5f        68
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f       186
# fulfilled1      0
# dtype: int64

# %%
df_cleaned= df.dropna()

# %%
df.shape
# Out:
# (5244, 14)

# %%
df_cleaned.shape
# Out:
# (4994, 14)

# %%
df_cleaned.to_csv("cleaned_data.csv",index=False)

# %%
cdf= pd.read_csv("cleaned_data.csv")

# %%
cdf.describe()
# Out:
#                  id       Rating     actprice1      norating1    noreviews1  \
# count   4994.000000  4994.000000   4994.000000    4994.000000   4994.000000
# mean   10518.902082     4.010913   1379.236884    2960.668202    410.375250
# std     5972.960848     0.302011   1283.855455   12440.017709   1835.883639
# min        0.000000     0.000000    162.000000       1.000000      0.000000
# 25%     5290.250000     3.900000    699.000000      66.000000      9.000000
# 50%    10571.000000     4.000000    999.000000     305.500000     43.000000
# 75%    15644.000000     4.200000   1299.000000    1424.250000    212.750000
# max    20964.000000     5.000000  15999.000000  289973.000000  45448.000000
#
#              star_5f       star_4f       star_3f       star_2f       star_1f  \
# count    4994.000000   4994.000000   4994.000000   4994.000000   4994.000000
# mean     1539.347217    632.774730    353.142771    153.150180    272.179415
# ...

# %%
cdf.isnull().sum()
# Out:
# id            0
# title         0
# Rating        0
# maincateg     0
# platform      0
# actprice1     0
# norating1     0
# noreviews1    0
# star_5f       0
# star_4f       0
# star_3f       0
# star_2f       0
# star_1f       0
# fulfilled1    0
# dtype: int64
